# %%
import pickle
import torch
import os
import matplotlib.pyplot as plt

# %%
# Define the directory to search in
directory = os.getcwd()
file_name = 'Sim_70.pickle'

with open(os.path.join(directory, file_name), 'rb') as file:
    # Do something with the file contents
    data = pickle.load(file)

# %%
# Out:
# {'I2_EH': tensor([0.0000, 0.0000, 0.0000,  ..., 0.0011, 0.0011, 0.0011]),
#  'I2_RN': tensor([0.0000, 0.0000, 0.0000,  ..., 0.0011, 0.0011, 0.0012]),
#  'b.c.': (tensor([[15.],
#           [15.],
#           [15.],
#           ...,
#           [15.],
#           [15.],
#           [15.]]),
#   tensor([[ 0.0000e+00],
#           [ 9.8974e-02],
#           [-9.8974e-02],
#           ...,
#           [-3.6022e-01],
#           [-1.8016e-01],
#           [ 1.3788e-06]]),
#   tensor([[ 0.1143],
#           [-0.0571],
#           [-0.0571],
#           ...,
#           [ 7.8775],
#           [ 7.8837],
#           [ 7.8857]]),
#   tensor([[-1.],
#           [-1.],
#           [-1.],
#           ...,
#           [-1.],
#           [-1.],
#           [-1.]]),
#   tensor([[0.],
#           [0.],
#           [0.],
#           ...,
#           [0.],
#           [0.],
#           [0.]]),
#   tensor([[0.],
#           [0.],
#           [0.],
#           ...,
#           [0.],
#           [0.],
# ...

# %%
yy
zz

fig, axs = plt.subplot_mosaic([['RN17', 'EH17', 'D']], figsize=(24, 8))
ax = axs['RN17']
cm = ax.scatter(yy, zz, marker='h', c=IM_A.view(-1, 1), cmap='hot')
ax.axis('equal')

Schw_Hor = plt.Circle((0, 0), 2, lw=2, ls='--', color='w', fill=False)
RN_Hor = plt.Circle((0, 0), r_H_RN, lw=2, ls='--', color='m', fill=False)

Schw_ph = plt.Circle((0, 0), 3, lw=2, ls='-', alpha=0.5, color='w', fill=False)
RN_ph_c = plt.Circle((0, 0), r_p_RN, lw=2, ls='-', alpha=0.5, color='m', fill=False)


ax.add_patch(Schw_Hor)
ax.add_patch(RN_Hor)
ax.add_patch(Schw_ph)
ax.add_patch(RN_ph_c)
ax.set_title('RN, 17 deg')
ax.set_xlabel('$Y/M$')
ax.set_ylabel('$Z/M$')
plt.colorbar(cm)


ax = axs['EH17']
cm = ax.scatter(yy, zz, marker='h', c=IM_B.view(-1, 1), cmap='hot')
Schw_Hor = plt.Circle((0, 0), 2, lw=2, ls='--', color='w', fill=False)
RN_Hor = plt.Circle((0, 0), r_H_EH, lw=2, ls='--', color='m', fill=False)
Schw_ph = plt.Circle((0, 0), 3, lw=2, ls='-', alpha=0.5, color='w', fill=False)
RN_ph_c = plt.Circle((0, 0), r_p_EH, lw=2, ls='-', alpha=0.5, color='m', fill=False)
ax.add_patch(Schw_Hor)
ax.add_patch(RN_Hor)
ax.add_patch(Schw_ph)
ax.add_patch(RN_ph_c)
plt.colorbar(cm)
ax.set_title('EH, 17 deg')
ax.set_xlabel('$Y/M$')
ax.set_ylabel('$Z/M$')
ax.axis('equal')
